# %% [markdown]
# ## 异常检测分析

# %% [markdown]
# -  **什么是异常检测**
# > 定义： 孤立点、离群、与众不同、超出范围、不在预期...
# > 原因： 测量误差、记录误差、随机、非随机其他因素导致...
# > 应用： 故障检测、网络入侵、欺诈分析、医疗药物...

# %% [markdown]
# -  **异常vs正常**
# > 一个人的异常可能是另一个人的信号  --推断来自抽样，应用需要谨慎
# 作为运动青年和普通青年的差异：
# ![科比](./kebb.png)

# %% [markdown]
# -  **异常检测方法**
# > 统计：非随机性
# > 聚类：无从归属
# > 密度：且看身边
# > 其他：距离、序列、偏差...

# %% [markdown]
# -  **统计--异常检测方法**

# %% [markdown]
# 看分布，3σ原则

# %%
library(repr)
par(mfrow = c(1, 2), ann = FALSE)
hist(rnorm(100),main='sdfff');
plot(1:30,main='b343');title('sd');
print('hello R!')
# Out:
# [1] "hello R!"
# Plot with title "sd"

# %% [markdown]
# 箱图，分位数

# %%
library(quantmod)
options("getSymbols.warning4.0"=FALSE)
getSymbols("^SSEC")
#
SSEC$t=rownames(SSEC);

#chartSeries(SSEC) 
candleChart(SSEC,theme='white', type='candles') 
#library(plotrix)
#n=nrow(SSEC);x=1:n;y1=SSEC$SSEC.Volum;y2=SSEC$SSEC.Close;
#twoord.plot(x,y1,x,y2,xlim=c(0,n),lylim=c(0,300000),rylim=c(2000,6000), lcol=4,rcol=2,xlab="name",ylab="volume",rylab="close",type=c("bar","b"),xticklab=SSEC$t,halfwidth=0.2)
# Out:
# [1] "SSEC"
# Plot with title "[2007-01-04/2016-06-13]"

# %%
#http://gallery.cortanaintelligence.com/Notebook/Changing-R-plot-options-in-Jupyter-6
# Change plot size to 4 x 3
options(repr.plot.width=4, repr.plot.height=3)
curve(sin(x), from = 0, to=2*pi, n = 100)
# Change plot size to 8 x 3
options(repr.plot.width=8, repr.plot.height=3)
curve(sin(x), from = 0, to=4*pi, n = 200)
# Out:
# plot without title
# plot without title

# %% [markdown]
# hello R! We can [plotly](https://plot.ly/r/using-r-in-jupyter-notebooks) U !

# %% [markdown]
# #lof 算法  https://en.wikipedia.org/wiki/Local_outlier_factor
# ![科比](./lof.png)

# %% [markdown]
# abccc

# %% [markdown]
# ## 参考
# ![1]:陈斌,陈松灿等,2009,"异常检测综述",山东大学学报.
# ![2]:cador,2014,"[使用R语言进行异常检测](http://youhaolin.blog.163.com/blog/static/224494120201422110628586/)".
# ![3]:杨风召,"[异常检测算法综述](http://www.docin.com/p-559232022.html)"
# ![4]:杨永铭,王喆,2008.01,"[孤立点挖掘算法研究](http://www.docin.com/p-559232022.html)",计算机与数字工程.
# ![5]:高磊,2013,"[虚假交易识别](http://gaolei786.github.io/statistics/fraud.html)"

# %% [markdown]
# bbb
#
# aaa
